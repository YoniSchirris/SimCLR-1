# %%
import sys
sys.path.append('..')
from modules.transformations.colour_normalization import CustomMacenkoNormalizer
from PIL import Image

# %%
target = '/Users/yoni/dropbox/uva/ai/nki/histogenomics-msc-2019/yoni-code/MsiPrediction/data/msidata/crc_dx/train/MSS/blk-TGINPMKGNHYS-TCGA-CK-5912-01Z-00-DX1.png'

paths = ['/Users/yoni/dropbox/uva/ai/nki/histogenomics-msc-2019/yoni-code/MsiPrediction/data/msidata/crc_dx/train/MSS/blk-TGINPMKGNHYS-TCGA-CK-5912-01Z-00-DX1.png',
'/Users/yoni/dropbox/uva/ai/nki/histogenomics-msc-2019/yoni-code/MsiPrediction/data/msidata/crc_dx/train/MSS/blk-TGINRMPEMKGT-TCGA-CM-6164-01Z-00-DX1.png',
'/Users/yoni/dropbox/uva/ai/nki/histogenomics-msc-2019/yoni-code/MsiPrediction/data/msidata/crc_dx/train/MSS/blk-TGIQPQRNNDKP-TCGA-D5-6541-01Z-00-DX1.png',
'/Users/yoni/dropbox/uva/ai/nki/histogenomics-msc-2019/yoni-code/MsiPrediction/data/msidata/crc_dx/train/MSS/blk-TGIRHSRCAQYG-TCGA-CM-6680-01Z-00-DX1.png',
'/Users/yoni/dropbox/uva/ai/nki/histogenomics-msc-2019/yoni-code/MsiPrediction/data/msidata/crc_dx/train/MSS/blk-TGISIQQEIMRF-TCGA-DT-5265-01Z-00-DX1.png',
'/Users/yoni/dropbox/uva/ai/nki/histogenomics-msc-2019/yoni-code/MsiPrediction/data/msidata/crc_dx/train/MSS/blk-TGITNDQQMMWS-TCGA-DC-6160-01Z-00-DX1.png',
'/Users/yoni/dropbox/uva/ai/nki/histogenomics-msc-2019/yoni-code/MsiPrediction/data/msidata/crc_dx/train/MSS/blk-TGITNLRWKWHY-TCGA-AA-3812-01Z-00-DX1.png',
'/Users/yoni/dropbox/uva/ai/nki/histogenomics-msc-2019/yoni-code/MsiPrediction/data/msidata/crc_dx/train/MSS/blk-TGIVHHDKVVAN-TCGA-AD-6890-01Z-00-DX1.png',
'/Users/yoni/dropbox/uva/ai/nki/histogenomics-msc-2019/yoni-code/MsiPrediction/data/msidata/crc_dx/train/MSS/blk-TGIWDKKNVAWG-TCGA-DM-A28M-01Z-00-DX1.png',
'/Users/yoni/dropbox/uva/ai/nki/histogenomics-msc-2019/yoni-code/MsiPrediction/data/msidata/crc_dx/train/MSS/blk-TGIWGAHFVPDD-TCGA-CM-5860-01Z-00-DX1.png']

# %%
import matplotlib.pyplot as plt
import time

import ipywidgets as widgets
import numpy as np

normalizer = CustomMacenkoNormalizer(target)

fig, axes = plt.subplots(nrows=len(paths), ncols=2, figsize=(4,20))
for i, path in enumerate(paths):
    im = Image.open(path)
    im = np.array(im)
    
    t1 = time.time()
    new_im = normalizer.transform(im)
    print(f"Transform took {time.time()-t1} seconds")
#     print((im==new_im).all())
    axes[i, 0].axis('off')
    axes[i, 0].imshow(Image.fromarray(im))
    axes[i, 1].axis('off')
    axes[i, 1].imshow(Image.fromarray(new_im))
#     plt.subplot(1,2,1)
#     plt.imshow(Image.fromarray(im))
#     plt.subplot(1,2,2)
#     plt.imshow(Image.fromarray(new_im))
    
    
#
# Out:
# Transform took 0.03564906120300293 seconds
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-7b49ad2345a8> in <module>
#      19     axes[i, 0].imshow(Image.fromarray(im))
#      20     axes[i, 1].axis('off')
# ---> 21     axes[i, 1].imshow(Image.fromarray(new_im))
#      22 #     plt.subplot(1,2,1)
#      23 #     plt.imshow(Image.fromarray(im))
#
# ~/miniconda3/envs/thesisp375_staintools/lib/python3.7/site-packages/PIL/Image.py in fromarray(obj, mode)
#    2768             obj = obj.tostring()
#    2769
# -> 2770     return frombuffer(mode, size, obj, "raw", rawmode, 0, 1)
#    2771
#    2772
#
# ~/miniconda3/envs/thesisp375_staintools/lib/python3.7/site-packages/PIL/Image.py in frombuffer(mode, size, data, decoder_name, *args)
#    2708             return im
#    2709
# -> 2710     return frombytes(mode, size, data, decoder_name, args)
#    2711
#    2712
#
# ...
