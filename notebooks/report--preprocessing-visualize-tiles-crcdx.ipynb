# %%
import pandas as pd
from PIL import Image
import os

# %%
df = pd.read_csv('/home/yonis/histogenomics-msc-2019/yoni-code/MsiPrediction/data/msidata/crc_dx/train/data.csv')
root = "/home/yonis/histogenomics-msc-2019/yoni-code/MsiPrediction/data/msidata/crc_dx/train/"

# %%
df.head()
# Out:
#    Unnamed: 0                                               img  label  \
# 0           0  MSS/blk-TGINPMKGNHYS-TCGA-CK-5912-01Z-00-DX1.png      0
# 1           1  MSS/blk-TGINRMPEMKGT-TCGA-CM-6164-01Z-00-DX1.png      0
# 2           2  MSS/blk-TGIQPQRNNDKP-TCGA-D5-6541-01Z-00-DX1.png      0
# 3           3  MSS/blk-TGIRHSRCAQYG-TCGA-CM-6680-01Z-00-DX1.png      0
# 4           4  MSS/blk-TGISIQQEIMRF-TCGA-DT-5265-01Z-00-DX1.png      0
#
#   patient_id
# 0       5912
# 1       6164
# 2       6541
# 3       6680
# 4       5265

# %%
for label in [0, 1]:
    for idx, row in df[df['label']==label].sample(frac=1).reset_index().iterrows():
        print("MSS" if label==0 else "MSI")
        display(Image.open(os.path.join(root, row['img'])))
        if idx == 2:
            break
# Out:
# MSS
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224 at 0x14FFCFCC4650>
# MSS
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224 at 0x14FFCE6C5750>
# MSS
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224 at 0x14FFCFA00450>
# MSI
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224 at 0x14FFCEFA6D50>
# MSI
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224 at 0x14FFCEFA6CD0>
# MSI
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224 at 0x14FFCEFA6D50>
